# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder,PolynomialFeatures #preprocessing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline #pipeline stuff
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.neighbors import KNeighborsClassifier #classifer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

train_data=pd.read_csv("train.csv")
test_data=pd.read_csv("test.csv")
X_train = train_data.drop(columns=['SalePrice']) 
y_train = train_data["SalePrice"]
X_test = test_data #no labels vec to confirm results,
print(X_train.to_numpy())
# Out:
# [[1 60 'RL' ... 2008 'WD' 'Normal']
#  [2 20 'RL' ... 2007 'WD' 'Normal']
#  [3 60 'RL' ... 2008 'WD' 'Normal']
#  ...
#  [1458 70 'RL' ... 2010 'WD' 'Normal']
#  [1459 20 'RL' ... 2010 'WD' 'Normal']
#  [1460 20 'RL' ... 2008 'WD' 'Normal']]

# %%
print(X_train.isna().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# Length: 80, dtype: int64

# %%
'''
things to do in the future:
1.remove the 'Street' column, they are all 'paved' so doesnt matter 

2. make a pipline set up so taht the test data can be swtiched up as well?

3.remove nans from the numerical columns with the imputer

4.encode
remember that one hot encoding is better for things without a 'order'
things to one hot encode:    (shouldnt need to give it all possible values, have it come up with something for nan stuff)
Street   <=== delete this one? all paved?
Alley
Lotconfig
Neighborhood
Condition1
Condition2
RoofStyle
RoofMatl
Exterior1st
Exterior2nd
MasVnrType
Foundation
Heating
Electrical
GarageType
MiscFeature
SaleType
SaleCondition
[[[[[
encoder = OrdinalEncoder(categories = [df['Sex'].unique()]) this will easily get the catagories, but will also take any nan values as a categore
]]]]]
-----------things to ordinally encode:-----------
MSSubClass
LotShape
LandContour
LandSlope
BldgType
HouseStyle
ExterQual
ExterCond
BsmtQual
BsmtCond
BsmtExposure
BsmtFinType1
BsmtFinType2
HeatingQC
CentralAir
KitchenQual
Functional
FireplaceQu
GarageFinish
GarageQual
GarageCond
PavedDrive
PoolQC
Fence
'''
# Out:
# "\nthings to do in the future:\n1.remove the 'Street' column, they are all 'paved' so doesnt matter \n\n2. make a pipline set up so taht the test data can be swtiched up as well?\n\n3.remove nans from the numerical columns with the imputer\n\n4.encode\nremember that one hot encoding is better for things without a 'order'\nthings to one hot encode:    (shouldnt need to give it all possible values, have it come up with something for nan stuff)\nStreet   <=== delete this one? all paved?\nAlley\nLotconfig\nNeighborhood\nCondition1\nCondition2\nRoofStyle\nRoofMatl\nExterior1st\nExterior2nd\nMasVnrType\nFoundation\nHeating\nElectrical\nGarageType\nMiscFeature\nSaleType\nSaleCondition\n[[[[[\nencoder = OrdinalEncoder(categories = [df['Sex'].unique()]) this will easily get the catagories, but will also take any nan values as a categore\n]]]]]\n-----------things to ordinally encode:-----------\nMSSubClass\nLotShape\nLandContour\nLandSlope\nBldgType\nHouseStyle\nExterQual\nExterCond\nBsmtQual\
# ...

# %%
numeric_features = ['LotFrontage','LotArea','OverallQual','OverallCond','YearBuilt','YearRemodAdd',
                    'MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF',
                    'LowQualFinSF','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','BedroomAbvGr','KitchenAbvGr',
                    'TotRmsAbvGrd','Fireplaces','GarageYrBlt','GarageCars','GarageArea','WoodDeckSF','OpenPorchSF',
                    'EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','MoSold','YrSold']

ordinal_features = ['MSSubClass', 'LotShape','LandContour','LandSlope','BldgType','HouseStyle','ExterQual'
                    ,'ExterCond','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
                    'HeatingQC','CentralAir','KitchenQual','Functional','FireplaceQu','GarageFinish',
                    'GarageQual','GarageCond','PavedDrive','PoolQC','Fence']

oneHotEncode_features = ['Alley','LotConfig','Neighborhood','Condition1','Condition2','RoofStyle',
                         'RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Foundation','Heating',
                         'Electrical','GarageType','MiscFeature','SaleType','SaleCondition']

# %%
#preproccessors
imputer_processor=Pipeline(steps = [
    ('imputer',SimpleImputer(strategy='constant')),
])
numeric_processor=Pipeline(steps = [
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
    ])
oneHotencoder_processor=Pipeline(steps = [
    ('1Hotencoder',OneHotEncoder(handle_unknown='ignore',min_frequency=.01))  #the ingore makes it so that a unknown value gets the [0,0,0,...,0] vector
    ])
ordinalencoder_processor = Pipeline(steps = [
    ('ordinalencoder',OrdinalEncoder(handle_unknown='use_encoded_value',unknown_value=999))
])

# %%
#transfromers
feature_processor = ColumnTransformer(transformers=[
    ('num',numeric_processor,numeric_features),
    ('1hotEncode',oneHotencoder_processor,oneHotEncode_features),
    ('ordinalencoder',ordinalencoder_processor,ordinal_features)],
    remainder='drop' #drop 'name' 'sibsp' and the other features that are not included in the feature lists used above                                
    )

# %%
imputedTemp = imputer_processor.fit_transform(X_train)
transformedTemp = feature_processor.fit_transform(pd.DataFrame(imputedTemp))
#print(imputedTemp[0])
print(transformedTemp[0])


pipe_temp = Pipeline(steps = [
    ('imputer',imputer_processor),
    ('feature_process',feature_processor)
])
#temp1 = pipe_temp.fit_transform(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 imputedTemp = imputer_processor.fit_transform(X_train)
# ----> 2 transformedTemp = feature_processor.fit_transform(pd.DataFrame(imputedTemp))
#       3 #print(imputedTemp[0])
#       4 print(transformedTemp[0])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
# ...

# %%
#final pipeline
pipe_clf = Pipeline(steps = [
    ('imputer',imputer_processor),
    ('feature_process',feature_processor),
    ('knn_clf',KNeighborsClassifier())
])
pipe_clf
# Out:
# Pipeline(steps=[('imputer',
#                  Pipeline(steps=[('imputer',
#                                   SimpleImputer(strategy='constant'))])),
#                 ('feature_process',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'B...
# ...

# %%
pipe_clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/_indexing.py:420, in _get_column_indices(X, key)
#     419 try:
# --> 420     all_columns = X.columns
#     421 except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pipe_clf.fit(X_train,y_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
# ...

# %%
'''
potentially take all the feature editing and then run it on the data to see if the encoding does what it needs to 

it seems that after the imputer the code gives a numpy array, which because it lacks the columns, this die (even if it is coverted back to a
dataframe, the column names are lost, hence losing things)
'''
