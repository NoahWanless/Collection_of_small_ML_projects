# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('bridge.csv', index_col='Date', parse_dates=True,thousands=',')
df.columns = ['total','west','east']
# Out:
# /var/folders/8t/y5v94x215r973w80szwrht8r0000gq/T/ipykernel_36674/4200061273.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('bridge.csv', index_col='Date', parse_dates=True,thousands=',')

# %%
df.head() #shows how many bikes cross a bridge per hour, with data+time, total that cross, total that cross going west and total that cross
#going east
# Out:
#                      total   west  east
# Date
# 2025-07-31 23:00:00   23.0   15.0   8.0
# 2025-07-31 22:00:00   82.0   68.0  14.0
# 2025-07-31 21:00:00  155.0  117.0  38.0
# 2025-07-31 20:00:00  185.0  151.0  34.0
# 2025-07-31 19:00:00  202.0  159.0  43.0

# %%
df.dtypes
# Out:
# total    float64
# west     float64
# east     float64
# dtype: object

# %%
df['total'].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
#Lets plot the total for March 2024, for just that month
march_24_data = df.loc['2024-03']['total']
march_24_data.plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
#doing just one day
march_24_day_data = df.loc['2024-03-14']['total']
march_24_day_data.plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
#now we are going to make a table, each column is a day, and each row is a hour in said day

df['hour'] = df.index.hour
df['date'] = df.index.date

table= df.pivot_table(values='total',index='hour',columns='date')
table.head()
# Out:
# date  2012-10-02  2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07  \
# hour
# 0            NaN        13.0        18.0        11.0        15.0        11.0
# 1            NaN        10.0         3.0         8.0        15.0        17.0
# 2            NaN         2.0         9.0         7.0         9.0         3.0
# 3            NaN         5.0         3.0         4.0         3.0         6.0
# 4            NaN         7.0         8.0         9.0         5.0         3.0
#
# date  2012-10-08  2012-10-09  2012-10-10  2012-10-11  ...  2025-07-22  \
# hour                                                  ...
# 0            9.0        12.0        15.0        21.0  ...        17.0
# 1            4.0         3.0         3.0        10.0  ...        10.0
# 2            5.0         4.0         3.0        13.0  ...         2.0
# 3            5.0         8.0         4.0         2.0  ...         6.0
# 4            5.0         9.0         5.0        12.0  ...        17.0
#
# date  2025-07-23  2025-07-24  2025-07-25  2025-07-26  2025-07-27  2025-07-28  \
# hour
# 0            7.0        10.0        21.0        47.0        39.0        17.0
# 1            4.0         8.0         9.0        18.0        21.0         3.0
# 2            7.0         8.0         4.0         7.0        11.0         3.0
# 3            5.0         5.0         6.0         5.0         9.0         6.0
# 4           16.0        16.0        10.0        10.0         7.0        12.0
#
# date  2025-07-29  2025-07-30  2025-07-31
# hour
# 0            9.0         5.0        12.0
# 1            7.0        11.0         2.0
# 2            3.0         1.0         3.0
# 3           15.0         5.0         7.0
# 4            9.0        18.0        12.0
#
# [5 rows x 4666 columns]

# %%
table.plot(figsize=(15,5),legend=False,alpha=.3)
# Out:
# <Axes: xlabel='hour'>
